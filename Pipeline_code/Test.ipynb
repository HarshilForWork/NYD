# %%
import pandas as pd

df1 = pd.read_csv('C:/PF/Projects/NYD/ramayana_fact_check_results.csv')
df2= pd.read_csv("C:/Users/harsh/Downloads/FINAL_PREDICTION_JBBR.csv")

# %%
df3= pd.merge(df1, df2, on='Prediction', how='outer')

# %%
# Find values in df2's Prediction column that are not in df1's Prediction column
different_predictions = df2[~df2['Prediction'].isin(df1['Prediction'])]

# Display the different predictions
print("Predictions in df2 that are not in df1:")
print(different_predictions['Prediction'])

# To see more details about these different predictions
print("\nFull rows from df2 where predictions differ:")
print(different_predictions)

# Get count of different predictions
print(f"\nTotal number of different predictions: {len(different_predictions)}")
# Out:
# Predictions in df2 that are not in df1:
# Series([], Name: Prediction, dtype: bool)
#
# Full rows from df2 where predictions differ:
# Empty DataFrame
# Columns: [Statement, Prediction]
# Index: []
#
# Total number of different predictions: 0
